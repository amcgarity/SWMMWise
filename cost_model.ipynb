# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from math import log10
from cost_model import *
gaPerSMP = [x*0.1 for x in range(1,21)]
#print gaPerSMP
privateCostPerGA = []
publicCostPerGA = []
for value in gaPerSMP:
    privateCostPerGA.append(private_cost_per_greened_acre(value))
    publicCostPerGA.append(public_cost_per_greened_acre(value))
#print gaPerSMP
##print privateCostPerGA
    
(fig, ax1) = plt.subplots()
ax1.plot(gaPerSMP,privateCostPerGA,color = 'b')
ax1.plot(gaPerSMP,publicCostPerGA,color = 'g')
ax1.set_xlabel("Greened Acre per SMP (Acre)",fontsize=12)
ax1.set_ylabel("Cost per Greened Acre ($)",fontsize=12)
#stdDevText = "Std. Dev. Residuals = %0.2f MGal" % stdDevResiduals
#ax1.text(2,-4,stdDevText)
print log10(150000)
# Out:
# 5.17609125906
